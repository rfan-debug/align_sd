# %%
from datasets import load_dataset

# %%
dataset = load_dataset('poloclub/diffusiondb', "large_first_10k", ignore_verifications=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/datasets/load.py:2097: FutureWarning: 'ignore_verifications' was deprecated in favor of 'verification_mode' in version 2.9.1 and will be removed in 3.0.0.
# You can remove this warning by passing 'verification_mode=no_checks' instead.
#   warnings.warn(
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset["train"][2]["image"]
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>
